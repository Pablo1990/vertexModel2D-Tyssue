# %% [markdown]
# <a href="https://colab.research.google.com/github/Pablo1990/vertexModel2D-Tyssue/blob/main/google_collab_main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install numpy scipy matplotlib pandas jupyter notebook quantities ipywidgets pythreejs ipyvolume vispy tyssue
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.2/101.2 kB 2.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 14.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 27.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 35.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 24.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.4/123.4 kB 17.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 271.7/271.7 kB 34.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 260.7/260.7 kB 36.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 36.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 38.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 38.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 42.0 MB/s eta 0:00:00
# ...

# %%
# %run auxFunctions.py
# %run brownianMotion.py
# %run inputMechanicalParameters.py
# %run vertexModel.py
# Out:
# collision solver could not be imported You may need to install CGAL and re-install tyssue

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

from tyssue.draw import sheet_view

# %%
# Initialize Model
[cellmap_init, geom, energyContributions_model] = initialize()

# Update mechanical parameters
cellmap_init = update(cellmap_init)

# Initial stage
energyContributions_model.compute_energy(cellmap_init)
# Out:
# 56324.2094799135

# %%
# RUN
[cellmap_H, geom, model_H, history_H] = solveEuler(cellmap_init, geom, energyContributions_model, endTime = 100)
# Out:
# Topology changed!
# Topology changed!
# Topology changed!
# Topology changed!
# Topology changed!
# Topology changed!
# Topology changed!
# Topology changed!
# Topology changed!
# Topology changed!
# Topology changed!
# Topology changed!
# Topology changed!
# Topology changed!
# Topology changed!
# Topology changed!
# Topology changed!
# Topology changed!
# Topology changed!
# Topology changed!
# Topology changed!
# Topology changed!
# Topology changed!
# Topology changed!
# Topology changed!
# Topology changed!
# Topology changed!
# Topology changed!
# Topology changed!
# Topology changed!
# Topology changed!
# Topology changed!
# Topology changed!
# Topology changed!
# Topology changed!
# Topology changed!

# %%
cellmap_H.edge_df["color_edges"] = cellmap_H.edge_df['length']/(max(cellmap_H.edge_df['length']))
cellmap_H.face_df["color_edges"] = cellmap_H.face_df['area']/(max(cellmap_H.face_df['area']))

## https://tyssue.readthedocs.io/en/latest/notebooks/02-Visualization.html
specs = {
    'face': {
        'visible': True,
        'color': cellmap_H.face_df["color_edges"],
    },
    'edge': {
        'visible': True,
        'color': cellmap_H.edge_df["color_edges"],
        'colormap':'Greys',
        'width': 1,
    },
    'vert': {
        'visible': True,
        's': 5,
    }
}
fig, ax = sheet_view(cellmap_H, **specs)
energyContributions_model.compute_energy(cellmap_init)
# Out:
# 1739.9289370956362

# %%
## This only works if you are in Linux and build the current branch
create_frames(history_H, './results', edge={'color':'black'})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-8100b12374fe> in <cell line: 2>()
#       1 ## This only works if you are in Linux and build the current branch
# ----> 2 create_frames(history_H, './results', edge={'color':'black'})
#
# /content/auxFunctions.py in create_frames(history, output, num_frames, interval, draw_func, margin, **draw_kwds)
#      59         start, stop = interval[0], interval[1]
#      60
# ---> 61     for i, (t, sheet) in enumerate(history.browse(start, stop, num_frames)):
#      62         try:
#      63             fig, ax = sheet_view(sheet, **draw_kwds)
#
# AttributeError: 'History' object has no attribute 'browse'
